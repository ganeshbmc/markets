# %% [markdown]
# <a href="https://colab.research.google.com/github/ganeshbmc/markets/blob/master/quant%20trading/volatility/iv_vs_rv_nifty_daily.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install breeze_connect
# !pip install yfinance
# !pip install pandas_ta

# %%
import pandas as pd
import numpy as np
import pandas_ta as ta
# import talib
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import math as m
import yfinance as yf
import breeze_connect
from breeze_connect import BreezeConnect

print("Imported necessary libraries")
# Out:
# Imported necessary libraries

# %% [markdown]
# ## Start breeze_connect

# %%
# Generate session token for each day  
# Log into this site while the 'developer tools -> network' tab is open (https://api.icicidirect.com/apiuser/login?api_key=06890j43os6a521A7b7241i934KQ9S56) 
# Copy 'API_session' key for 'payload' section in 127.0.0.1  

fresh_token = 7622102

# %%
isec = BreezeConnect(api_key="06890j43os6a521A7b7241i934KQ9S56")
isec.generate_session(
    api_secret="$42367K2z98758S712349896J6i^64Mx",
    session_token=fresh_token)

# %% [markdown]
# ## Data for FY2022-2023

# %%
# start_date = dt.date(2022,4,1)
# end_date = dt.date(2023,4, 1)
# start_date, end_date

# %%
# Get data from yfinance

# Nifty daily

# df = yf.download(tickers="^NSEI", interval="1d", start=start_date, end=end_date)
# df.to_csv("nifty_daily_fy_22-23.csv")

# Indiavix daily - NOT working
# df = yf.download(tickers="^INDIAVIX", interval="1d", start=start_date, end=end_date)
# df.to_csv("indiavix_daily_fy_22-23.csv")

# Got Indiavix data from investing.com
# dfv = pd.read_html("file:///home/ganesh/Downloads/vix.html")[0]
# dfv.to_csv("indiavix_daily_fy_22-23.csv")

# %%
# Get nifty data stored in a local file
# nifty = pd.read_excel("/home/ganesh/Github/markets/quant trading/volatility/nifty_daily_fy_22_23.xlsx")
# nifty.tail()

# %%
# Get indiavix data stored in a local file
# vix = pd.read_excel("/home/ganesh/Github/markets/quant trading/volatility/indiavix_daily_fy_22_23.xlsx")
# vix["Date"] = pd.to_datetime(vix["Date"], format="%b %d, %Y")
# vix.sort_values(by="Date", inplace=True)
# vix = vix.iloc[1:, :]
# vix

# %%
# Get nifty data using breeze_connect

# nifty_dict = isec.get_historical_data(
#     interval="1day", 
#     from_date=start_date.strftime("%Y-%m-%d"), 
#     to_date=end_date.strftime("%Y-%m-%d"),
#     stock_code="NIFTY",
#     exchange_code="NSE",
#     product_type="",
#     expiry_date="")

# # nifty_dict 

# nifty = pd.DataFrame(nifty_dict['Success'])
# print(nifty.shape)
# print(nifty.columns)
# nifty.tail()

# %%
# Get indiavix data using breeze_connect

# vix_dict = isec.get_historical_data(
#     interval="1day", 
#     from_date=start_date.strftime("%Y-%m-%d"), 
#     to_date=end_date.strftime("%Y-%m-%d"),
#     stock_code="INDVIX",
#     exchange_code="NSE",
#     product_type="",
#     expiry_date="")

# # vix_dict 

# vix = pd.DataFrame(vix_dict['Success'])
# print(vix.shape)
# print(vix.columns)
# vix.tail()

# %% [markdown]
# ### Function to get data in required format using breeze_connect

# %%
def get_data_using_breeze(client, stock_code: str, interval: str, from_date: str, to_date: str) -> pd.DataFrame:
    data_dict = client.get_historical_data(interval=interval, 
                                        from_date=from_date, 
                                        to_date=to_date,
                                        stock_code=stock_code,
                                        exchange_code="NSE",
                                        product_type="",
                                        expiry_date="")
    df = pd.DataFrame(data_dict["Success"])
    df = df[['datetime', 'open', 'high', 'low', 'close', 'volume']]
    df["datetime"] = pd.to_datetime(df["datetime"], format="%Y-%m-%d %H:%M:%S")
    df[['open', 'high', 'low', 'close', 'volume']] = df[['open', 'high', 'low', 'close', 'volume']].astype(float)
    return df

# %%
nifty = get_data_using_breeze(isec, "NIFTY", "1day", "2018-04-01", "2023-03-31")
vix = get_data_using_breeze(isec, "INDVIX", "1day", "2018-04-01", "2023-03-31")

nifty.shape, vix.shape
# Out:
# ((1241, 6), (1241, 6))

# %% [markdown]
# ### Function for IV based predictions

# %%
def iv_based_predictions(spot_price, atm_iv, days_to_expiry=1, risk_stddev=1.25):
    exp_move_pct = (atm_iv/(np.sqrt(256/days_to_expiry)))
    exp_move_pct_for_desired_risk = exp_move_pct * risk_stddev
    # return exp_move_pct, exp_move_pct_for_desired_risk
    points_move = (spot_price * (exp_move_pct_for_desired_risk/100)).round(0)
    lower_strike = (spot_price - points_move).round(0)
    upper_strike = (spot_price + points_move).round(0)
    return exp_move_pct_for_desired_risk, points_move, lower_strike, upper_strike

# %%
def add_volatility_based_measures(underlying_ohlcv: pd.DataFrame, 
                                    volatility_ohlcv: pd.DataFrame,
                                    days_to_expiry: float,
                                    risk_stddev: float) -> pd.DataFrame:
    # Add realized volatility measures
    data = underlying_ohlcv.copy()
    data["points_move"] = data["close"].diff().round()
    data["abs_points_move"] = abs(data["points_move"])
    data["returns"] = data["close"].pct_change()

    # Add implied volatility measures FOR INTRADAY
    data["indiavix"] = volatility_ohlcv["open"]
    data[["exp_move_pct", "exp_points_move", "lower", "upper"]] = data.apply(lambda x: iv_based_predictions(x.open, x.indiavix, days_to_expiry, risk_stddev), axis=1, result_type="expand")
    data["overshoot"] = data.apply(lambda x: (x["abs_points_move"] > x["exp_points_move"]), axis=1)
    data["overshoot_points"] = data.apply(lambda x: abs(x["abs_points_move"] - x["exp_points_move"]), axis=1)
    data["overshoot_points"] =  np.where(data["overshoot"] == False, np.NaN, data["overshoot_points"])

    return data

# %%
dff = add_volatility_based_measures(nifty, vix, days_to_expiry=1, risk_stddev=1.5)
dff
# Out:
#                 datetime      open      high       low     close  \
# 0    2018-04-02 12:04:00  10151.65  10220.10  10127.75  10211.80
# 1    2018-04-03 12:04:00  10186.85  10255.35  10171.05  10245.00
# 2    2018-04-04 12:04:00  10274.60  10279.85  10111.30  10128.40
# 3    2018-04-05 12:04:00  10228.45  10331.80  10227.45  10325.15
# 4    2018-04-06 12:04:00  10322.75  10350.45  10290.85  10331.60
# ...                  ...       ...       ...       ...       ...
# 1236 2023-03-24 12:03:00  17076.20  17109.45  16917.35  16945.05
# 1237 2023-03-27 12:03:00  16984.30  17091.00  16918.55  16985.70
# 1238 2023-03-28 12:03:00  17031.75  17061.75  16913.75  16951.70
# 1239 2023-03-29 12:03:00  16977.30  17126.15  16940.60  17080.70
# 1240 2023-03-31 12:03:00  17210.35  17381.60  17204.65  17359.75
#
#             volume  points_move  abs_points_move   returns  indiavix  \
# 0     1.246128e+09          NaN              NaN       NaN     15.76
# 1     1.485609e+09         33.0             33.0  0.003251     15.35
# 2     1.822045e+09       -117.0            117.0 -0.011381     15.19
# 3     1.625293e+09        197.0            197.0  0.019426     16.34
# 4     1.629632e+09          6.0              6.0  0.000625     14.80
# ...            ...          ...              ...       ...       ...
# 1236  2.021980e+09       -132.0            132.0 -0.007721     14.49
# 1237  2.203406e+08         41.0             41.0  0.002399     15.24
# 1238  2.164428e+08        -34.0             34.0 -0.002002     15.45
# 1239  2.913668e+08        129.0            129.0  0.007610     15.10
# 1240  2.650966e+08        279.0            279.0  0.016337     13.63
#
#       exp_move_pct  exp_points_move    lower    upper  overshoot  \
# 0         1.477500            150.0  10002.0  10302.0      False
# 1         1.439062            147.0  10040.0  10334.0      False
# 2         1.424063            146.0  10129.0  10421.0      False
# 3         1.531875            157.0  10071.0  10385.0       True
# 4         1.387500            143.0  10180.0  10466.0      False
# ...            ...              ...      ...      ...        ...
# 1236      1.358437            232.0  16844.0  17308.0      False
# 1237      1.428750            243.0  16741.0  17227.0      False
# 1238      1.448437            247.0  16785.0  17279.0      False
# 1239      1.415625            240.0  16737.0  17217.0      False
# 1240      1.277813            220.0  16990.0  17430.0       True
#
#       overshoot_points
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                 40.0
# 4                  NaN
# ...                ...
# 1236               NaN
# 1237               NaN
# 1238               NaN
# 1239               NaN
# 1240              59.0
#
# [1241 rows x 16 columns]

# %%
sns.lineplot(data=dff[["abs_points_move", "exp_points_move"]])
# Out:
# <AxesSubplot:>

# %%
dff["overshoot"].value_counts()
# Out:
# False    1158
# True       83
# Name: overshoot, dtype: int64

# %%
overshoot_pct = dff["overshoot"].value_counts()[True] / dff.shape[0]
overshoot_pct.round(2)
# Out:
# 0.07

# %% [markdown]
# # Add technical indicators

# %% [markdown]
# ### Function to add techincal indicators using pandas_ta library

# %%
def add_technical_indicators(df: pd.DataFrame,
                                strategy: ta.Strategy):
    df_with_indicators = df.copy()
    df_with_indicators.ta.strategy(strategy)
    return df_with_indicators

# %%
# Define a custom strategy with technical indicators of interest  

custom_strategy = ta.Strategy(
    name = "SEAR",
    ta=[
    {"kind": "sma", "length": 20},
    {"kind": "ema", "length": 20},
    {"kind": "rsi", "length": 14},
    {"kind": "adx", "length": 14}
    ]
)

# %%
dfvt = add_technical_indicators(dff, custom_strategy)
dfvt
# Out:
#                 datetime      open      high       low     close  \
# 0    2018-04-02 12:04:00  10151.65  10220.10  10127.75  10211.80
# 1    2018-04-03 12:04:00  10186.85  10255.35  10171.05  10245.00
# 2    2018-04-04 12:04:00  10274.60  10279.85  10111.30  10128.40
# 3    2018-04-05 12:04:00  10228.45  10331.80  10227.45  10325.15
# 4    2018-04-06 12:04:00  10322.75  10350.45  10290.85  10331.60
# ...                  ...       ...       ...       ...       ...
# 1236 2023-03-24 12:03:00  17076.20  17109.45  16917.35  16945.05
# 1237 2023-03-27 12:03:00  16984.30  17091.00  16918.55  16985.70
# 1238 2023-03-28 12:03:00  17031.75  17061.75  16913.75  16951.70
# 1239 2023-03-29 12:03:00  16977.30  17126.15  16940.60  17080.70
# 1240 2023-03-31 12:03:00  17210.35  17381.60  17204.65  17359.75
#
#             volume  points_move  abs_points_move   returns  indiavix  ...  \
# 0     1.246128e+09          NaN              NaN       NaN     15.76  ...
# 1     1.485609e+09         33.0             33.0  0.003251     15.35  ...
# 2     1.822045e+09       -117.0            117.0 -0.011381     15.19  ...
# 3     1.625293e+09        197.0            197.0  0.019426     16.34  ...
# 4     1.629632e+09          6.0              6.0  0.000625     14.80  ...
# ...            ...          ...              ...       ...       ...  ...
# 1236  2.021980e+09       -132.0            132.0 -0.007721     14.49  ...
# 1237  2.203406e+08         41.0             41.0  0.002399     15.24  ...
# 1238  2.164428e+08        -34.0             34.0 -0.002002     15.45  ...
# 1239  2.913668e+08        129.0            129.0  0.007610     15.10  ...
# 1240  2.650966e+08        279.0            279.0  0.016337     13.63  ...
#
#         lower    upper  overshoot  overshoot_points      SMA_20        EMA_20  \
# 0     10002.0  10302.0      False               NaN         NaN           NaN
# 1     10040.0  10334.0      False               NaN         NaN           NaN
# 2     10129.0  10421.0      False               NaN         NaN           NaN
# 3     10071.0  10385.0       True              40.0         NaN           NaN
# 4     10180.0  10466.0      False               NaN         NaN           NaN
# ...       ...      ...        ...               ...         ...           ...
# 1236  16844.0  17308.0      False               NaN  17276.1550  17263.324512
# 1237  16741.0  17227.0      False               NaN  17252.1500  17236.884082
# 1238  16785.0  17279.0      False               NaN  17230.1000  17209.723693
# 1239  16737.0  17217.0      False               NaN  17218.9375  17197.435723
# 1240  16990.0  17430.0       True              59.0  17214.3800  17212.894225
#
#          RSI_14     ADX_14     DMP_14     DMN_14
# 0           NaN        NaN        NaN        NaN
# 1           NaN        NaN        NaN        NaN
# 2           NaN        NaN        NaN        NaN
# 3           NaN        NaN        NaN        NaN
# 4           NaN        NaN        NaN        NaN
# ...         ...        ...        ...        ...
# 1236  35.551229  29.444079  14.614978  33.611415
# 1237  37.373047  30.154511  13.718601  31.549934
# 1238  36.445081  30.831708  12.982666  30.031420
# 1239  42.299073  30.909819  14.449916  28.003173
# 1240  52.492923  29.183918  21.882194  25.048723
#
# [1241 rows x 22 columns]

# %%
dfvt.columns
# Out:
# Index(['datetime', 'open', 'high', 'low', 'close', 'volume', 'points_move',
#        'abs_points_move', 'returns', 'indiavix', 'exp_move_pct',
#        'exp_points_move', 'lower', 'upper', 'overshoot', 'overshoot_points',
#        'SMA_20', 'EMA_20', 'RSI_14', 'ADX_14', 'DMP_14', 'DMN_14'],
#       dtype='object')

# %% [markdown]
# # Visualize data

# %%
overshoots = dfvt.loc[dfvt["overshoot"] == True]
overshoots["close"].size
# Out:
# 83

# %%
timeline = dfvt["datetime"]

spot_close = dfvt["close"]
upper_pred = dfvt["upper"]
lower_pred = dfvt["lower"]

plt.rcParams["figure.figsize"] = (20, 8)
plt.plot(timeline, spot_close, color='b', label='spot')

plt.plot(timeline, upper_pred, color='r', label='upper')
plt.plot(timeline, lower_pred, color='y', label='lower')

overshoots = dfvt.loc[dfvt["overshoot"] == True]["close"]
tl = dfvt.loc[dfvt["overshoot"] == True]["datetime"]
plt.scatter(tl, overshoots)

plt.legend()
plt.show()

# %%
timeline = dfvt["datetime"]

rsi = dfvt["RSI_14"]
adx = dfvt["ADX_14"]

plt.rcParams["figure.figsize"] = (20, 8)

plt.plot(timeline, rsi, color='g', label='rsi')
plt.plot(timeline, adx, color='r', label='adx')

overshoots_rsi= dfvt.loc[dfvt["overshoot"] == True]["RSI_14"]
overshoots_adx = dfvt.loc[dfvt["overshoot"] == True]["ADX_14"]
tl = dfvt.loc[dfvt["overshoot"] == True]["datetime"]
plt.scatter(tl, overshoots_rsi)
plt.scatter(tl, overshoots_adx)

plt.legend()
plt.show()

# %% [markdown]
# # Expiry day analysis

# %% [markdown]
# ### Function to look at data day-wise

# %%
def day_wise_analysis(df: pd.DataFrame, day: str) -> pd.DataFrame:
    dfd = df.copy()
    dfd["day"] = dfd["datetime"].dt.day_name()
    dfd = dfd.loc[dfd["day"] == day]
    return dfd

# %%
dfvt_thu = day_wise_analysis(dfvt, "Thursday")
dfvt_thu.shape
# Out:
# (248, 23)

# %%
sns.lineplot(data=dfvt_thu[["abs_points_move", "exp_points_move"]])
# Out:
# <AxesSubplot:>

# %%
dfvt_thu_overshoot = dfvt_thu.loc[dfvt_thu["overshoot"] == True]
dfvt_thu_overshoot.shape
# Out:
# (18, 23)

# %%
dfvt_thu_overshoot.tail()
# Out:
#                 datetime      open      high       low    close        volume  \
# 1018 2022-05-12 12:05:00  16021.10  16041.95  15735.75  15808.0  2.413097e+08
# 1023 2022-05-19 12:05:00  15917.40  15984.75  15775.20  15809.4  2.125623e+09
# 1043 2022-06-16 12:06:00  15832.25  15863.15  15335.10  15360.6  2.031871e+09
# 1073 2022-07-28 12:07:00  16774.85  16947.65  16746.25  16929.6  2.285168e+08
# 1167 2022-12-15 12:12:00  18614.40  18652.90  18387.70  18414.9  5.031329e+08
#
#       points_move  abs_points_move   returns  indiavix  ...    upper  \
# 1018       -359.0            359.0 -0.022212     22.80  ...  16363.0
# 1023       -431.0            431.0 -0.026533     22.30  ...  16250.0
# 1043       -332.0            332.0 -0.021128     22.15  ...  16161.0
# 1073        288.0            288.0  0.017294     18.13  ...  17060.0
# 1167       -245.0            245.0 -0.013151     12.89  ...  18839.0
#
#       overshoot  overshoot_points      SMA_20        EMA_20     RSI_14  \
# 1018       True              17.0  16886.8850  16750.965351  27.176927
# 1023       True              98.0  16569.8175  16453.036095  33.755201
# 1043       True               3.0  16235.8350  16156.877376  29.254481
# 1073       True               3.0  16256.0600  16346.011937  69.103229
# 1167       True              20.0  18530.7125  18490.447388  49.979069
#
#          ADX_14     DMP_14     DMN_14       day
# 1018  23.177109  13.483254  40.923520  Thursday
# 1023  26.621050  18.205940  37.152529  Thursday
# 1043  20.533818  13.872771  37.969556  Thursday
# 1073  17.866153  36.250334  18.622002  Thursday
# 1167  17.100174  23.584054  30.439463  Thursday
#
# [5 rows x 23 columns]

# %%
dfvt_thu_overshoot.tail()["datetime"].dt.date
# Out:
# 1018    2022-05-12
# 1023    2022-05-19
# 1043    2022-06-16
# 1073    2022-07-28
# 1167    2022-12-15
# Name: datetime, dtype: object

# %%
dfvt_thu_overshoot[['close', 'indiavix', 'overshoot_points']].describe().T
# Out:
#                   count          mean          std      min         25%  \
# close              18.0  13517.733333  3147.035890  9590.15  10757.4000
# indiavix           18.0     19.238333     4.324418    12.89     16.5525
# overshoot_points   18.0     87.888889   156.529602     2.00      3.7500
#
#                         50%         75%       max
# close             12029.825  16138.3125  18414.90
# indiavix             18.015     21.8600     31.56
# overshoot_points     30.000     73.7500    571.00

# %%
# dfvt.to_excel("dfvt_intraday_fy_18_23.xlsx")
