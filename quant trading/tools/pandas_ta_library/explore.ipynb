# %%
import pandas as pd
import pandas_ta as ta
import talib
import yfinance as yf
import  matplotlib.pyplot as plt
import seaborn as sns

# %%
# Get data the first time

# df = pd.DataFrame()
# df = df.ta.ticker("^NSEI")
# print(df.shape)
# df.to_csv("nifty_daily_07042023.csv")

# %%
# Import data from local file
df = pd.read_csv("/home/ganesh/Github/markets/quant trading/tools/pandas_ta_library/nifty_daily_07042023.csv")
# print(df.tail())

# %%
df.shape
# Out:
# (3812, 8)

# %%
df = df.iloc[-300:, :]

# %%
df.shape
# Out:
# (300, 8)

# %% [markdown]
# ## Add indicators

# %%
df.ta.sma(length=20, append=True)
df.ta.ema(length=20, append=True)
df.ta.adx(length=14, append=True)
df.ta.rsi(length=14, append=True)
print(df.tail())
# Out:
#                            Date          Open          High           Low  \
# 3807  2023-03-29 00:00:00+05:30  16977.300781  17126.150391  16940.599609
# 3808  2023-03-31 00:00:00+05:30  17210.349609  17381.599609  17204.650391
# 3809  2023-04-03 00:00:00+05:30  17427.949219  17428.050781  17312.750000
# 3810  2023-04-05 00:00:00+05:30  17422.300781  17570.550781  17402.699219
# 3811  2023-04-06 00:00:00+05:30  17533.849609  17638.699219  17502.849609
#
#              Close  Volume  Dividends  Stock Splits        SMA_20  \
# 3807  17080.699219  345900        0.0           0.0  17218.937598
# 3808  17359.750000  263900        0.0           0.0  17214.380078
# 3809  17398.050781  230200        0.0           0.0  17218.187598
# 3810  17557.050781  248300        0.0           0.0  17216.322656
# 3811  17599.150391  242700        0.0           0.0  17210.707715
#
#             EMA_20     ADX_14     DMP_14     DMN_14     RSI_14
# 3807  17197.435693  30.909778  14.449969  28.003214  42.299039
# 3808  17212.894199  29.183882  21.882213  25.048756  52.492924
# 3809  17230.528159  27.306562  22.650080  24.003694  53.701930
# 3810  17261.625551  25.930641  26.426631  22.491798  58.431375
# 3811  17293.770774  24.994125  27.630392  21.351232  59.607921

# %%
sns.lineplot(x=df.Date, y=df.RSI_14)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='RSI_14'>

# %%
sns.lineplot(x=df.Date, y=df.ADX_14)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='ADX_14'>

# %%
# Out:
# ['candles',
#  'cycles',
#  'momentum',
#  'overlap',
#  'performance',
#  'statistics',
#  'trend',
#  'volatility',
#  'volume']
