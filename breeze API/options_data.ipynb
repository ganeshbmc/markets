# %%
import breeze_connect
from breeze_connect import BreezeConnect

# %%
# Generate session token for each day  
# Log into this site while the 'developer tools -> network' tab is open  
# Copy 'API_session' key for 'payload' section in 127.0.0.1  

fresh_token = 1733333

# %%
breeze = BreezeConnect(api_key="06890j43os6a521A7b7241i934KQ9S56")
breeze.generate_session(
    api_secret="$42367K2z98758S712349896J6i^64Mx",
    session_token=fresh_token)

# %% [markdown]
# `Options data`
#
# Not working for some unknown reason

# %%
breeze.get_option_chain_quotes(stock_code='NIFTY',
                                exchange_code='nfo',
                                product_type='options',
                                expiry_date='2022-10-27T06:00:00.000Z',
                                right='call',
                                strike_price='17500')
# Out:
# {'Success': None,
#  'Status': 500,
#  'Error': 'TPESVCFAIL - application level service failure (T4:253)'}

# %% [markdown]
# `Historical data`

# %%
breeze.get_historical_data(interval="1minute",
                            from_date= "2022-08-15T07:00:00.000Z",
                            to_date= "2022-08-17T07:00:00.000Z",
                            stock_code="ICIBAN",
                            exchange_code="NFO",
                            product_type="futures",
                            expiry_date="2022-08-25T07:00:00.000Z",
                            right="others",
                            strike_price="0")
# Out:
# {'Success': [{'datetime': '2022-08-16 09:15:00',
#    'stock_code': 'ICIBAN',
#    'exchange_code': 'NFO',
#    'product_type': 'Futures',
#    'expiry_date': '25-AUG-22',
#    'right': 'Others',
#    'strike_price': '0',
#    'open': '886.4',
#    'high': '887.25',
#    'low': '885',
#    'close': '886.2',
#    'volume': '783750',
#    'open_interest': '72773250',
#    'count': 0},
#   {'datetime': '2022-08-16 09:16:00',
#    'stock_code': 'ICIBAN',
#    'exchange_code': 'NFO',
#    'product_type': 'Futures',
#    'expiry_date': '25-AUG-22',
#    'right': 'Others',
#    'strike_price': '0',
#    'open': '886.7',
#    'high': '887',
#    'low': '886',
#    'close': '886.15',
#    'volume': '438625',
#    'open_interest': '72773250',
#    'count': 1},
#   {'datetime': '2022-08-16 09:17:00',
#    'stock_code': 'ICIBAN',
#    'exchange_code': 'NFO',
#    'product_type': 'Futures',
#    'expiry_date': '25-AUG-22',
#    'right': 'Others',
#    'strike_price': '0',
#    'open': '886.5',
# ...
